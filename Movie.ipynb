# %%
import pandas as  pd

# %%
df=pd.read_csv("/content/movies.csv")

# %%
df
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   21-12-1937    Musical           G
# 1                          Pinocchio   09-02-1940  Adventure           G
# 2                           Fantasia   13-11-1940    Musical           G
# 3                  Song of the South   12-11-1946  Adventure           G
# 4                         Cinderella   15-02-1950      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   02-09-2016      Drama       PG-13
# 575                   Queen of Katwe   23-09-2016      Drama          PG
# 576                   Doctor Strange   04-11-2016  Adventure       PG-13
# 577                            Moana   23-11-2016  Adventure          PG
# 578     Rogue One: A Star Wars Story   16-12-2016  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
df.head()
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   21-12-1937    Musical           G
# 1                        Pinocchio   09-02-1940  Adventure           G
# 2                         Fantasia   13-11-1940    Musical           G
# 3                Song of the South   12-11-1946  Adventure           G
# 4                       Cinderella   15-02-1950      Drama           G
#
#    total_gross  inflation_adjusted_gross
# 0    184925485                5228953251
# 1     84300000                2188229052
# 2     83320000                2187090808
# 3     65000000                1078510579
# 4     85000000                 920608730

# %%
df1=df.sort_values(by=['total_gross'], ascending=[False])

# %%
df1
# Out:
#                                 movie_title release_date      genre  \
# 564    Star Wars Ep. VII: The Force Awakens   18-12-2015  Adventure
# 524                            The Avengers   04-05-2012     Action
# 578            Rogue One: A Star Wars Story   16-12-2016  Adventure
# 571                            Finding Dory   17-06-2016  Adventure
# 558                 Avengers: Age of Ultron   01-05-2015     Action
# ..                                      ...          ...        ...
# 511                                Zokkomon   22-04-2011  Adventure
# 20   The Many Adventures of Winnie the Pooh   11-03-1977        NaN
# 29                                Condorman   07-08-1981     Action
# 355                     Frank McKlusky C.I.   01-01-2002        NaN
# 27                                      Amy   20-03-1981      Drama
#
#     mpaa_rating  total_gross  inflation_adjusted_gross
# 564       PG-13    936662225                 936662225
# ...

# %%
df1.describe()
# Out:
#         total_gross  inflation_adjusted_gross
# count  5.790000e+02              5.790000e+02
# mean   6.470179e+07              1.187625e+08
# std    9.301301e+07              2.860853e+08
# min    0.000000e+00              0.000000e+00
# 25%    1.278886e+07              2.274123e+07
# 50%    3.070245e+07              5.515978e+07
# 75%    7.570903e+07              1.192020e+08
# max    9.366622e+08              5.228953e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               579 non-null    object
#  1   release_date              579 non-null    object
#  2   genre                     562 non-null    object
#  3   mpaa_rating               523 non-null    object
#  4   total_gross               579 non-null    int64
#  5   inflation_adjusted_gross  579 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 27.3+ KB

# %%
df.shape
# Out:
# (579, 6)

# %%
df.agg("movie_title")
# Out:
# 0      Snow White and the Seven Dwarfs
# 1                            Pinocchio
# 2                             Fantasia
# 3                    Song of the South
# 4                           Cinderella
#                     ...
# 574           The Light Between Oceans
# 575                     Queen of Katwe
# 576                     Doctor Strange
# 577                              Moana
# 578       Rogue One: A Star Wars Story
# Name: movie_title, Length: 579, dtype: object

# %%
df.isnull().sum()
# Out:
# movie_title                  0
# release_date                 0
# genre                       17
# mpaa_rating                 56
# total_gross                  0
# inflation_adjusted_gross     0
# dtype: int64

# %%
df.mean()
# Out:
# <ipython-input-75-c61f0c8f89b5>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# total_gross                 6.470179e+07
# inflation_adjusted_gross    1.187625e+08
# dtype: float64

# %%
result = df.fillna(df.mean())
# Out:
# <ipython-input-76-1a7642d354fa>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   result = df.fillna(df.mean())

# %%
result
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   21-12-1937    Musical           G
# 1                          Pinocchio   09-02-1940  Adventure           G
# 2                           Fantasia   13-11-1940    Musical           G
# 3                  Song of the South   12-11-1946  Adventure           G
# 4                         Cinderella   15-02-1950      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   02-09-2016      Drama       PG-13
# 575                   Queen of Katwe   23-09-2016      Drama          PG
# 576                   Doctor Strange   04-11-2016  Adventure       PG-13
# 577                            Moana   23-11-2016  Adventure          PG
# 578     Rogue One: A Star Wars Story   16-12-2016  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.hist(bins=30, figsize=(8,5))
plt.show()

# %%
df1.corr()
# Out:
#                           total_gross  inflation_adjusted_gross
# total_gross                  1.000000                  0.427064
# inflation_adjusted_gross     0.427064                  1.000000

# %%
X_test = df.iloc[:,:]

# %%
X_test
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   21-12-1937    Musical           G
# 1                          Pinocchio   09-02-1940  Adventure           G
# 2                           Fantasia   13-11-1940    Musical           G
# 3                  Song of the South   12-11-1946  Adventure           G
# 4                         Cinderella   15-02-1950      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   02-09-2016      Drama       PG-13
# 575                   Queen of Katwe   23-09-2016      Drama          PG
# 576                   Doctor Strange   04-11-2016  Adventure       PG-13
# 577                            Moana   23-11-2016  Adventure          PG
# 578     Rogue One: A Star Wars Story   16-12-2016  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
y_train = df.total_gross

# %%
y_train
# Out:
# 0      184925485
# 1       84300000
# 2       83320000
# 3       65000000
# 4       85000000
#          ...
# 574     12545979
# 575      8874389
# 576    232532923
# 577    246082029
# 578    529483936
# Name: total_gross, Length: 579, dtype: int64

# %%
X_train = df.iloc[:,0:12]

# %%
X_train.head(3)
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   21-12-1937    Musical           G
# 1                        Pinocchio   09-02-1940  Adventure           G
# 2                         Fantasia   13-11-1940    Musical           G
#
#    total_gross  inflation_adjusted_gross
# 0    184925485                5228953251
# 1     84300000                2188229052
# 2     83320000                2187090808

# %%
df.drop(['movie_title','genre'], axis=1)
# Out:
#     release_date mpaa_rating  total_gross  inflation_adjusted_gross
# 0     21-12-1937           G    184925485                5228953251
# 1     09-02-1940           G     84300000                2188229052
# 2     13-11-1940           G     83320000                2187090808
# 3     12-11-1946           G     65000000                1078510579
# 4     15-02-1950           G     85000000                 920608730
# ..           ...         ...          ...                       ...
# 574   02-09-2016       PG-13     12545979                  12545979
# 575   23-09-2016          PG      8874389                   8874389
# 576   04-11-2016       PG-13    232532923                 232532923
# 577   23-11-2016          PG    246082029                 246082029
# 578   16-12-2016       PG-13    529483936                 529483936
#
# [579 rows x 4 columns]

# %%
inputs = df.drop('total_gross',axis='columns')
target = df.total_gross
